# %% [markdown]
# # 探索性数据分析（EDA）

# %%
import pandas as pd
import matplotlib.pyplot as plt
df = pd.read_csv('../data/AAPL.csv', parse_dates=['date'], index_col='date')
df['close'].plot(figsize=(10, 4), title='Close Curve')
plt.savefig('close_curve.png', dpi=120)
plt.show()
